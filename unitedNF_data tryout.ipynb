# %%
# !pip install yfinance==0.2.38
# !pip install pandas==2.2.2
# Out:
# ...
#      ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#      ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#      - -------------------------------------- 0.1/3.0 MB 1.2 MB/s eta 0:00:03
#      --- ------------------------------------ 0.3/3.0 MB 2.5 MB/s eta 0:00:02
#      --------- ------------------------------ 0.7/3.0 MB 4.6 MB/s eta 0:00:01
#      ----------------- ---------------------- 1.3/3.0 MB 6.2 MB/s eta 0:00:01
#      ------------------------ --------------- 1.8/3.0 MB 7.2 MB/s eta 0:00:01
#      ------------------------------- -------- 2.3/3.0 MB 7.8 MB/s eta 0:00:01
#      -------------------------------------- - 2.9/3.0 MB 8.3 MB/s eta 0:00:01
#      ---------------------------------------- 3.0/3.0 MB 7.5 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
# ...

# %%
import yfinance as yf
import pandas as pd

# %%
unitedNF = yf.Ticker("UNFI")

# %%
unitedNF_data = unitedNF.history(period = "max")

# %%
unitedNF_data
# Out:
#                             Open   High     Low  Close   Volume  Dividends  \
# Date
# 1996-11-01 00:00:00-05:00   6.75   7.00   6.625   6.75  3783600        0.0
# 1996-11-04 00:00:00-05:00   7.00   7.00   6.750   6.75   529600        0.0
# 1996-11-05 00:00:00-05:00   6.75   7.00   6.750   6.75   358000        0.0
# 1996-11-06 00:00:00-05:00   7.00   7.00   6.750   6.75   182200        0.0
# 1996-11-07 00:00:00-05:00   6.75   7.00   6.750   6.75   158800        0.0
# ...                          ...    ...     ...    ...      ...        ...
# 2024-05-31 00:00:00-04:00  11.76  12.08  11.740  12.01   869800        0.0
# 2024-06-03 00:00:00-04:00  12.07  12.35  12.010  12.32   509400        0.0
# 2024-06-04 00:00:00-04:00  12.27  12.42  12.050  12.14   778400        0.0
# 2024-06-05 00:00:00-04:00  12.86  13.77  12.600  13.40  1844900        0.0
# 2024-06-06 00:00:00-04:00  13.57  15.64  13.500  15.54  1753000        0.0
#
#                            Stock Splits
# Date
# ...

# %%
unitedNF_data.reset_index(inplace=True)
unitedNF_data.plot(x="Date", y="Open")
# Out:
# <Axes: xlabel='Date'>
